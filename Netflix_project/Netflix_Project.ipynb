# %%
import pandas as pd

# %%
df1=pd.read_json("C:/Users/91728/OneDrive/Desktop/Pandas_prac/Netflix_project/netflix1.json")
df1
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   str
#  1   type          8790 non-null   str
#  2   title         8790 non-null   str
#  3   director      8790 non-null   str
#  4   country       8790 non-null   str
#  5   date_added    8790 non-null   str
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   str
#  8   duration      8790 non-null   str
#  9   listed_in     8790 non-null   str
# dtypes: int64(1), str(9)
# memory usage: 686.8 KB

# %%
#Deleting redudant colums
#Rename the colums
#Dropping duplicates
#Remove the NaN values from the data set
#check for more Transformations

# %%
df1.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in'],
#       dtype='str')

# %%
data=df1.drop(columns='rating') #Deleting the redundant colums
data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'country', 'date_added',
#        'release_year', 'duration', 'listed_in'],
#       dtype='str')

# %%
data=data.rename(columns={'show_id':'id','director':'Maker'})
data.columns
# Out:
# Index(['id', 'type', 'title', 'Maker', 'country', 'date_added', 'release_year',
#        'duration', 'listed_in'],
#       dtype='str')

# %%
new_columns=[]
for i in data.columns:
    new_columns.append(i.capitalize())

# %%
data.columns=new_columns
data.columns
# Out:
# Index(['Id', 'Type', 'Title', 'Maker', 'Country', 'Date_added', 'Release_year',
#        'Duration', 'Listed_in'],
#       dtype='str')

# %%
data.duplicated().sum()
data.drop_duplicates()
data.isna()
data.dropna()
# Out:
#          Id     Type                             Title            Maker  \
# 0        s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1        s3  TV Show                         Ganglands  Julien Leclercq
# 2        s6  TV Show                     Midnight Mass    Mike Flanagan
# 3       s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4        s8    Movie                           Sankofa     Haile Gerima
# ...     ...      ...                               ...              ...
# 8785  s8797  TV Show                        Yunus Emre        Not Given
# 8786  s8798  TV Show                         Zak Storm        Not Given
# 8787  s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788  s8784  TV Show                              Yoko        Not Given
# 8789  s8786  TV Show                               YOM        Not Given
#
#             Country  Date_added  Release_year   Duration  \
# ...

# %%
data["Id"].unique()
data["Id"]=data["Id"].str.split('S').replace['']
data
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[51], line 2
#       1 data["Id"].unique()
# ----> 2 data["Id"]=data["Id"].str.split('S').replace['']
#       3
#
# File c:\Users\91728\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:6206, in NDFrame.__getattr__(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# File c:\Users\91728\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\accessor.py:230, in Accessor.__get__(self, obj, cls)
#     227 if obj is None:
#     228     # we're accessing the attribute of the class, i.e., Dataset.geo
#     229     return self._accessor
# ...
